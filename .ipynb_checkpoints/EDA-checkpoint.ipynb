# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Loading data from movie.csv
df = pd.read_csv('DATA/movies.csv')
df.head()
# Out:
#                              movie  year                             genres  \
# 0                            Wazir  2016       ['Action', 'Crime', 'Drama']
# 1                      On the Road  2012  ['Adventure', 'Drama', 'Romance']
# 2  The Secret Life of Walter Mitty  2013   ['Adventure', 'Comedy', 'Drama']
# 3      A Walk Among the Tombstones  2014       ['Action', 'Crime', 'Drama']
# 4                   Jurassic World  2015  ['Action', 'Adventure', 'Sci-Fi']
#
#    runtime_minutes  averagerating  numvotes   studio  domestic_gross  \
# 0            103.0            7.1     15378  Relbig.       1100000.0
# 1            124.0            6.1     37886      IFC        744000.0
# 2            114.0            7.3    275300      Fox      58200000.0
# 3            114.0            6.5    105116     Uni.      26300000.0
# 4            124.0            7.0    539338     Uni.     652300000.0
#
#    foreign_gross
# 0            0.0
# 1      8000000.0
# 2    129900000.0
# 3     26900000.0
# 4         1019.4

# %% [markdown]
# ### Analyzing the dataset

# %%
#checking summary statistics for numerical features
df.describe()
# Out:
#              movie         year  runtime_minutes  averagerating      numvotes  \
# count     2.000000  3055.000000      3055.000000    3055.000000  3.055000e+03
# mean   1135.500000  2013.810147       107.234043       6.464255  6.269165e+04
# std    1096.722618     2.455890        19.971703       0.992565  1.255432e+05
# min     360.000000  2010.000000         3.000000       1.600000  5.000000e+00
# 25%     747.750000  2012.000000        94.000000       5.900000  2.483000e+03
# 50%    1135.500000  2014.000000       105.000000       6.600000  1.371300e+04
# 75%    1523.250000  2016.000000       118.000000       7.100000  6.610850e+04
# max    1911.000000  2019.000000       272.000000       9.200000  1.841066e+06
#
#        domestic_gross  foreign_gross
# count    3.055000e+03   3.055000e+03
# mean     3.055992e+07   4.707447e+07
# std      6.663005e+07   1.143039e+08
# min      1.000000e+02   0.000000e+00
# 25%      1.420000e+05   0.000000e+00
# 50%      2.000000e+06   2.100000e+06
# 75%      3.205000e+07   3.350000e+07
# max      7.001000e+08   9.464000e+08

# %%
#Checking the shape of the dataset. It has 3055 rows and 9 columns.
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (3055, 9)

# %%
#Summarize the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3055 entries, 0 to 3054
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie            2 non-null      float64
#  1   year             3055 non-null   int64
#  2   genres           3055 non-null   object
#  3   runtime_minutes  3055 non-null   float64
#  4   averagerating    3055 non-null   float64
#  5   numvotes         3055 non-null   int64
#  6   studio           3055 non-null   object
#  7   domestic_gross   3055 non-null   float64
#  8   foreign_gross    3055 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 214.9+ KB

# %% [markdown]
# The dataset has no missing values

# %%
#Checking duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Visualize distributions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Calculate total gross
df["total_gross"] = df["domestic_gross"] + df["foreign_gross"]

# %%
# Group by year and sum total gross
gross_by_year = df.groupby("year")["total_gross"].sum().reset_index()

# %%
#Plotting a line chart
plt.figure(figsize=(10, 5))
plt.plot(gross_by_year["year"], gross_by_year["total_gross"], marker='o')
plt.title("Total Gross Revenue by Year")
plt.xlabel("Year")
plt.ylabel("Total Gross (Domestic + Foreign)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import ast

# %%
# Convert genres from string to list
df["genres"] = df["genres"].apply(ast.literal_eval)

# %%
# Explode the genres so each genre has its own row
exploded_df = df.explode("genres")

# %%
# Count how many times each genre appears per year
genre_counts = exploded_df.groupby(["year", "genres"]).size().reset_index(name="count")

# %%
# Get the top 6 genres across all years
top_genres = genre_pivot.sum().sort_values(ascending=False).head(6).index

# %%
# Filter to show only the top genres
top_genre_data = genre_pivot[top_genres]

# %%
# Plotting a grouped barchart
top_genre_data.plot(kind="bar", figsize=(14, 7))
plt.title("Top 6 Most Frequently Released Genres Over the Years")
plt.xlabel("Year")
plt.ylabel("Number of Movies Released")
plt.legend(title="Genre")
plt.tight_layout()
plt.grid(True)
plt.show()
